# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df1 = pd.read_csv('wgnd_source.csv', usecols=['name', 'code', 'gender'])

# %%
# pd.set_option('max_rows', None)

# %%
Anil Dhagedf2 = pd.read_csv('wgnd_noctry.csv')

# %%
df3 = pd.read_csv('wgnd_langctry.csv', usecols=['name', 'gender'])

# %%
Anil Dhagedf4 = pd.read_csv('wgnd_ctry.csv')
# Out:
#   File "<ipython-input-11-92815f8a3b25>", line 1
#     Anil Dhagedf4 = pd.read_csv('wgnd_ctry.csv')
#          ^
# SyntaxError: invalid syntax

# %%
df1.shape

# %%
df2.shape

# %%
df3.shape
# Out:
# (175917, 2)

# %%
type(df3)
# Out:
# NoneType

# %%
df4.shape
# Out:
# (175916, 2)

# %%
df2.shape

# %%
df4 = df3.drop_duplicates(subset= ['name','gender'] , keep='first')

# %%
df4 = df4.dropna()

# %%
df4.head(100)
# Out:
#           name gender
# 0     A HANNAN      M
# 50       A JAY      M
# 100    A K I L      M
# 150      A LAH      F
# 200      A RIN      F
# ...        ...    ...
# 3735     AAHAN      M
# 3785    AAHANA      F
# 3835     AAHIL      M
# 3885   AAHLIAH      F
# 3935  AAHLIANA      F
#
# [100 rows x 2 columns]

# %%
df3 = df3.dropna()

# %%
df4 = df4[df4['name'].str.contains(" ")]
df4.to_csv('names_with_space_char.csv')

# %%
df3.head(100)
# Out:
#         name gender
# 0   A HANNAN      M
# 1   A HANNAN      M
# 2   A HANNAN      M
# 3   A HANNAN      M
# 4   A HANNAN      M
# 5   A HANNAN      M
# 6   A HANNAN      M
# 7   A HANNAN      M
# 8   A HANNAN      M
# 9   A HANNAN      M
# 10  A HANNAN      M
# 11  A HANNAN      M
# 12  A HANNAN      M
# 13  A HANNAN      M
# 14  A HANNAN      M
# 15  A HANNAN      M
# 16  A HANNAN      M
# 17  A HANNAN      M
# 18  A HANNAN      M
# 19  A HANNAN      M
# 20  A HANNAN      M
# 21  A HANNAN      M
# 22  A HANNAN      M
# 23  A HANNAN      M
# 24  A HANNAN      M
# 25  A HANNAN      M
# 26  A HANNAN      M
# 27  A HANNAN      M
# 28  A HANNAN      M
# 29  A HANNAN      M
# 30  A HANNAN      M
# 31  A HANNAN      M
# 32  A HANNAN      M
# 33  A HANNAN      M
# 34  A HANNAN      M
# 35  A HANNAN      M
# 36  A HANNAN      M
# 37  A HANNAN      M
# 38  A HANNAN      M
# 39  A HANNAN      M
# 40  A HANNAN      M
# 41  A HANNAN      M
# 42  A HANNAN      M
# 43  A HANNAN      M
# ...

# %%
d4.head(Anil Dhage)

# %% [markdown]
# df3 has 6 million records, hence we will work on this

# %%
Anil Dhagedf3.isnull().sum()

# %%
# Anil Dhagedf3.dropna(inplace=True)
df4.isnull().sum()
# Out:
# name      0
# gender    0
# dtype: int64

# %%
Anil Dhagedf3.shape

# %%
pd.set_option("max_rows", None)

# %%
#6276093:6277038
#df = df3.drop(df3.index[6276093:6277038])

# %%
#removed non english script
df = df3.iloc[0:6276000,:]

# %%
df['first_name'] = df['name'].str.split(' ').str[0]
df['middle_name'] = df['name'].str.split(' ').str[1]
df['last_name'] = df['name'].str.split(' ').str[2]

# %%
Anil Dhagedf.head()

# %%
new_df = df[[ 'first_name', 'middle_name', 'last_name', 'gender', 'code']]

# %%
#new_df.to_csv('clean_dataset.csv')
